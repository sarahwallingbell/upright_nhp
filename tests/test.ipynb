# %%
import pandas as pd
import os
from primate_uprighting.upright import upright_nrn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# programs\celltypes\workgroups\mousecelltypes\SarahWB\github_projects\primate_uprighting\testing\test.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell://allen/programs/celltypes/workgroups/mousecelltypes/SarahWB/github_projects/primate_uprighting/testing/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell://allen/programs/celltypes/workgroups/mousecelltypes/SarahWB/github_projects/primate_uprighting/testing/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import os
# ----> <a href='vscode-notebook-cell://allen/programs/celltypes/workgroups/mousecelltypes/SarahWB/github_projects/primate_uprighting/testing/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from primate_uprighting.upright import upright_nrn
#
# ModuleNotFoundError: No module named 'primate_uprighting'

# %%
csv =r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\github_projects\primate_uprighting\testing\specimens.csv'
#raw/orginal file 
o_out = r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\github_projects\primate_uprighting\testing\original_new'
upright_out = r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\github_projects\primate_uprighting\testing\upright_new'

#make dirs if they don't exist 
if not os.path.isdir(upright_out): os.mkdir(upright_out)  
if not os.path.isdir(o_out): os.mkdir(o_out)

specimen_id_column = 'specimen_id'

# %%
# ##Check any conditions you need to HERE
df = pd.read_csv(csv)
df[specimen_id_column] = [a.replace(u'\u200b', '') for a in df[specimen_id_column].values]
print(len(df))
df.head()
# Out:
# 20
#           specimen_name specimen_id area medial_side_to_viewerpov
# 0   Q21.26.013.12.03.01  1102613885   Pu                    right
# 1  Q21.26.013.12.02.03​  1102623321   Pu                    right
# 2   Q21.26.019.13.01.02  1110880399   Ca                    right
# 3   Q21.26.019.13.01.05  1110896667   Ca                    right
# 4   Q21.26.020.14.05.02  1112128140  ACB                     left

# %%
#upright all cells in dataframe
cells_with_issues = {}
for ix, row in df.iterrows():
    
    specimen_id = row[specimen_id_column]
    oout = os.path.join(o_out, "{}.swc".format(specimen_id))
    uout = os.path.join(upright_out, "{}_upright.swc".format(specimen_id))

    _, cells_with_issues = upright_nrn(specimen_id, oout, uout, cells_with_issues)

# %%
cells_with_issues
# Out:
# {'1079081411': 'Could not load layers'}
